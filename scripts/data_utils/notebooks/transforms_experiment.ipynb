# %%
import os
import sys
from matplotlib import pyplot as plt
from PIL import Image
from torchvision import transforms as T

# %%
print(sys.path)
# Out:
# ['/Users/varundhingra/miniconda3/envs/runway/lib/python310.zip', '/Users/varundhingra/miniconda3/envs/runway/lib/python3.10', '/Users/varundhingra/miniconda3/envs/runway/lib/python3.10/lib-dynload', '', '/Users/varundhingra/miniconda3/envs/runway/lib/python3.10/site-packages', '/var/folders/sl/tqc80k9s4xngd8vhqyz9h5kh0000gn/T/tmpqkx3bf8c', '../scripts', '../scripts', '../../scripts', '../scripts']

# %%
sys.path.append("../scripts")
from data_utils.transforms import train_transforms, validate_transforms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 sys.path.append("../scripts")
# ----> 2 from data_utils.transforms import train_transforms, validate_transforms
#
# ModuleNotFoundError: No module named 'data_utils'

# %%
print(os.getcwd())
print(sys.path)
# Out:
# /Users/varundhingra/Desktop/runway_classification/notebooks
# ['/Users/varundhingra/miniconda3/envs/runway/lib/python310.zip', '/Users/varundhingra/miniconda3/envs/runway/lib/python3.10', '/Users/varundhingra/miniconda3/envs/runway/lib/python3.10/lib-dynload', '', '/Users/varundhingra/miniconda3/envs/runway/lib/python3.10/site-packages', '/var/folders/sl/tqc80k9s4xngd8vhqyz9h5kh0000gn/T/tmpqkx3bf8c', '../scripts', '../scripts', '../../scripts', '../scripts']
